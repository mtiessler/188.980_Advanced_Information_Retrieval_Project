# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python main_submit.py
# Out:
# C:/Users/hubin/TULokal/AIRLocal/longeval_sci_training_2025_abstract\longeval_sci_training_2025_abstract\queries_2024-11_test.txt
# C:/Users/hubin/TULokal/AIRLocal/longeval_sci_training_2025_abstract\longeval_sci_training_2025_abstract\queries_2025-01_test.txt
# ...
# Scanning doc files for IDs: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
#
# ...
# Loading required fields: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
#
# Re-gathering IDs for cache: 0it [00:00, ?it/s]
#
# Streaming doc files:   0%|          | 0/1 [00:00<?, ?it/s]
# Re-gathering IDs for cache: 6726it [00:00, 65377.74it/s]
# Re-gathering IDs for cache: 15584it [00:00, 77224.56it/s]
# Re-gathering IDs for cache: 24244it [00:00, 80302.48it/s]
# Re-gathering IDs for cache: 33127it [00:00, 83350.23it/s]
# Re-gathering IDs for cache: 41466it [00:00, 81395.83it/s]
# Re-gathering IDs for cache: 49864it [00:00, 81462.95it/s]
# Re-gathering IDs for cache: 58603it [00:00, 82237.17it/s]
# ...

# %% [markdown]
# Verify Submission

# %%
# verify

submission_candiate_directory = "submissions/Submission_BM25"
#submission_candiate_directory = "submissions/Submission_BERT"
#submission_candiate_directory = "submissions/Submission_RERANK"

# !tira-cli upload --dataset sci-20250430-test --dry-run --directory {submission_candiate_directory}
# Out:
# submissions/Submission_BM25
# I will upload the submission in directory 'submissions/Submission_BM25' to TIRA.
#
# I will check that the data in submissions\Submission_BM25 is valid ...
# 	✓ The run in subdirectory 2024-11 is valid.
# 	✓ The run in subdirectory 2025-01 is valid.
# 	✖ The file submissions\Submission_BM25/ir-metadata.yml is not valid. Errors:
# 		- The required field tag still contains the default value ENTER_VALUE_HERE.
# 		- The required field actor.team still contains the default value ENTER_VALUE_HERE.
# 		- The required field research goal.description still contains the default value ENTER_VALUE_HERE.
# 		- The required field implementation.source.repository still contains the default value ENTER_VALUE_HERE.
# 		- The required field data.training data.name still contains the default value ENTER_VALUE_HERE.
# 		- The required field method.automatic still contains the default value ENTER_VALUE_HERE.
# ...

# %% [markdown]
# SUBMIT it!

# %%
# verify
submission_candiate_directory = "submissions/Submission_BM25"
#submission_candiate_directory = "submissions/Submission_BERT"
#submission_candiate_directory = "submissions/Submission_RERANK"

# !tira-cli upload --dataset sci-20250430-test --dry-run --directory {submission_candiate_directory}

# submit:
print(f"Submiting: ", submission_candiate_directory)

# Academy Retrievals


# First login via your token from TIRA.io submission page
# !tira-cli login --token YOUR-TOKEN-FROM-TIRA-IO

''' 
# UNCOMMENT THIS TO UPLOAD YOUR SUBMISSION!!
# !tira-cli upload --dataset sci-20250430-test --directory {submission_candiate_directory}
'''
# Out:
# Submiting  submissions/Submission_BM25
# '\n# First login via your token from TIRA.io submission page\ntira-cli login --token YOUR-TOKEN-FROM-TIRA-IO\ntira-cli upload --dataset sci-20250430-test --directory sci-submission-skeleton\n'
